# %%
import os
import subprocess
from matplotlib import pyplot as plt
import numpy as np
import importlib
import copy
import statistics as stats
import random
import networkx as nx
import os
import seaborn as sns

# %%
def get_pair(filename, train, test):
    trains=[]
    tests=[]
    names=[]
    with open(filename,"r") as fh:
        for y in fh:
            y=y.split()
            if int(y[5])>=train and int(y[6])>=test:
                names.append(y[0])
                trains.append(int(y[5]))
                tests.append(int(y[6]))
            
    return trains,tests, names

# %%
def display_medians(data):
    for alg in data.keys():
        print(alg)
        print("training median: "+str(np.median(data[alg][0])))
        print("test median: "+str(np.median(data[alg][1])))

# %%
def get_restricted_data(data, algs):
    r_data={}
    name_set=[]
    for alg in algs:
        if len(name_set)==0:
            name_set=set(data[alg][2])
        else:
            name_set=name_set.intersection(set(data[alg][2]))
    print("there are "+str(len(name_set))+" common families")
    for alg in algs:
        new_trains=[]
        new_tests=[]
        new_names=[]
        for i in range(len(data[alg][0])):
            if data[alg][2][i] in name_set:
                new_names.append(data[alg][2][i])
                new_trains.append(data[alg][0][i])
                new_tests.append(data[alg][1][i])
        r_data[alg]=(new_trains,new_tests,new_names)
    return r_data

# %%
full_data={}
algs=['blue', 'cobalt','cluster','random70']
for alg in algs:
    train_sizes,test_sizes, names=get_pair("splits/full/"+alg+"_25_full_cat.tbl", 400, 20)
    full_data[alg]=(train_sizes, test_sizes, names)
display_medians(full_data)
r_full_data=get_restricted_data(full_data, algs)
display_medians(r_full_data)
r_full_data=get_restricted_data(full_data, algs[0:3])
display_medians(r_full_data)
# Out:
# blue
# training median: 1023.0
# test median: 46.5
# cobalt
# training median: 1205.5
# test median: 49.0
# cluster
# training median: 2711.0
# test median: 52.0
# random70
# training median: 6022.0
# test median: 37.0
# there are 262 common families
# blue
# training median: 3316.0
# test median: 610.0
# cobalt
# training median: 3527.0
# test median: 643.0
# cluster
# training median: 7421.0
# test median: 221.0
# random70
# training median: 5502.5
# test median: 35.0
# there are 1334 common families
# blue
# training median: 1424.5
# test median: 145.5
# cobalt
# training median: 1673.0
# test median: 139.5
# cluster
# training median: 2689.0
# test median: 51.0

# %%
seed_data={}
algs=['blue1','blue40','cobalt1','cobalt40','cluster','random70']
for alg in algs:
    train_sizes,test_sizes, names=get_pair("/n/home01/spetti/spetti_space/benchmarking/splits/"+alg+"_25.tbl", 10, 2)
    seed_data[alg]=(train_sizes, test_sizes, names)
display_medians(seed_data)
r_seed_data=get_restricted_data(seed_data, algs)
display_medians(r_seed_data)
r_seed_data=get_restricted_data(seed_data, algs[0:5])
display_medians(r_seed_data)
# Out:
# blue1
# training median: 39.0
# test median: 6.0
# blue40
# training median: 34.0
# test median: 6.0
# cobalt1
# training median: 43.0
# test median: 6.0
# cobalt40
# training median: 35.0
# test median: 7.0
# cluster
# training median: 43.0
# test median: 6.0
# random70
# training median: 52.0
# test median: 3.0
# there are 688 common families
# blue1
# training median: 47.0
# test median: 17.0
# blue40
# training median: 48.0
# test median: 24.0
# cobalt1
# training median: 52.0
# test median: 16.0
# cobalt40
# training median: 49.0
# test median: 24.0
# cluster
# training median: 54.0
# test median: 16.0
# random70
# training median: 61.0
# test median: 3.0
# there are 1759 common families
# blue1
# training median: 42.0
# test median: 10.0
# blue40
# training median: 42.0
# test median: 16.0
# cobalt1
# training median: 46.0
# test median: 10.0
# cobalt40
# training median: 43.0
# test median: 16.0
# cluster
# training median: 53.0
# test median: 8.0

# %%
def plot(data, save_name, myxlim, myylim,r_data=False):
    for alg in data.keys():
    #pos=poss[i]
   # i+=1
        #sns.set(rc={'figure.figsize':(3,3)})
        mp=sns.jointplot(x=data[alg][0], y=data[alg][1], kind='kde', xlim=myxlim, ylim=myylim, height=3.5)
        sns.scatterplot([np.median(data[alg][0])],[np.median(data[alg][1])],ax=mp.ax_joint, color='tab:green')
        if r_data!='False' and alg in r_data.keys():
            sns.scatterplot([np.median(r_data[alg][0])],[np.median(r_data[alg][1])],ax=mp.ax_joint, s=75, color='white', marker='x')
        mp.ax_joint.set_xscale('log')
        mp.ax_joint.set_yscale('log')
        mp.set_axis_labels('Training set size', 'Test set size',fontsize=10)
        plt.savefig("/n/home01/spetti/figures/"+save_name+"_"+alg+".pdf", bbox_inches='tight')

# %%
plot(full_data,'full',(400,100000),(20,5000), r_full_data)

# %%
plot(seed_data,'seed', (10,1000), (2,200), r_seed_data)
